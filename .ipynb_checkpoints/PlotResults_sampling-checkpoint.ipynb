# %%
import numpy as np
import matplotlib.pyplot as plt
import pylab as pil

# %%
import seaborn as sns

# %%
sns.set()

# %% [markdown]
# First let's load the Planck data and the base $\Lambda$CDM model prediction

# %%
Planck_CMB_TT = np.loadtxt('Planck_CMB_TT_spectra.dat')

# %%
GR_cl  = np.loadtxt('testGR_scalCls.dat')
GR_pk = np.loadtxt('testGR_matterpower.dat')

# %% [markdown]
# Then let's laod the computed $C_{\ell}^{TT}$ for each successful reconstruction

# %%
cls = np.loadtxt('sampler_counts_GBD_plus_xDE_cls_TT.dat')

# %%
cls.shape
# Out:
# (8, 799)

# %%
plt.semilogx(GR_cl[:,0], GR_cl[:,1], label=r'$\Lambda$CDM', linestyle='--', linewidth=1 ,color = 'black', zorder=4)
plt.errorbar(Planck_CMB_TT[:,0], Planck_CMB_TT[:,1], yerr=[Planck_CMB_TT[:,2], Planck_CMB_TT[:,3]], linewidth=0.5, fmt='none', color = 'red', alpha=0.5,zorder=2)
plt.scatter(Planck_CMB_TT[:,0], Planck_CMB_TT[:,1], color='red', alpha=0.5, s=15.0, zorder=3,label='Planck TT')


for i in range(cls.shape[0]):   
    plt.semilogx(range(2,cls.shape[1]+2), cls[i,:], linewidth=1, color='C0', alpha=0.5, zorder=1)
    
#plt.semilogx(range(2,cls.shape[1]+2), cls[0,:], linewidth=10, color='C0', linestyle = '-', alpha=1, zorder=1)
#plt.semilogx(range(2,cls.shape[1]+2), cls[1,:], linewidth=7, color='C1', linestyle = '-',alpha=1, zorder=2)
#plt.semilogx(range(2,cls.shape[1]+2), cls[2,:], linewidth=5, color='C2', linestyle = '-',alpha=1, zorder=3)
#plt.semilogx(range(2,cls.shape[1]+2), cls[3,:], linewidth=3, color='C3', linestyle = '-', alpha=1, zorder=4)
#plt.semilogx(range(2,cls.shape[1]+2), cls[4,:], linewidth=1, color='C4', linestyle = '-',alpha=0.5, zorder=5)
#plt.semilogx(range(2,cls.shape[0]+2), cls, linewidth=0.5, color='C0', alpha=0.2)
plt.xlim(2,2000)
plt.ylim(0,7e3)
plt.legend(loc='upper left')
plt.xlabel(r'$\ell$')
plt.ylabel(r'$\ell (\ell+1) / (2 \pi) \, C_{\ell}^{\rm TT}$')
pil.savefig('sampling_cls_test.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# Now we want to check which $X(a)$ are giving successful reconstructions.

# %%
avec = np.loadtxt('sampler_counts_GBD_plus_xDE_a_sample.dat')

# %%
xDE = np.loadtxt('sampler_counts_GBD_plus_xDE_sampled.dat')

# %%
avec.shape
# Out:
# (40,)

# %%
xDE.shape
# Out:
# (5, 40)

# %%
for i in range(xDE.shape[0]):
    plt.plot(avec, xDE[i,:], color = 'C0', alpha=0.2)
#plt.plot(avec, xDE, color = 'C0', alpha=0.2)
plt.axhline(1.0, color='black', label=r'$\Lambda$CDM', linewidth = 1.0, linestyle='--')
plt.legend(loc='lower right')
plt.xlim(0,1)
plt.ylim(-3,2)
plt.xlabel(r'$a$')
plt.ylabel(r'$X(a)$')
pil.savefig('sampling_xDE_test.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# We are also interested in which initial conditions are giving us successful reconstructions

# %%
init_cond = np.loadtxt('sampler_counts_GBD_plus_init_cond.dat')
# Out:
# /Users/alexzucca/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: loadtxt: Empty input file: "sampler_counts_GBD_plus_init_cond.dat"
#   """Entry point for launching an IPython kernel.

# %%
init_cond.shape
# Out:
# (0,)

# %%
index_list = [1,3]

# %%
plt.scatter(init_cond[:,3], init_cond[:,1],alpha=0.2)
plt.ylim(-1e-6,1e-6)
plt.xlim(-3,-0.5)
plt.xlabel(r'$\log_{10} a_{\rm ini}$')
plt.ylabel(r'$\phi_{\rm ini}^{\prime} / m_0$')
pil.savefig('sampling_IC_test.pdf', bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-225-b62d6038f87f> in <module>()
# ----> 1 plt.scatter(init_cond[:,3], init_cond[:,1],alpha=0.2)
#       2 plt.ylim(-1e-6,1e-6)
#       3 plt.xlim(-3,-0.5)
#       4 plt.xlabel(r'$\log_{10} a_{\rm ini}$')
#       5 plt.ylabel(r'$\phi_{\rm ini}^{\prime} / m_0$')
#
# IndexError: too many indices for array

# %%
omega = np.loadtxt('sampler_counts_GBD_plus_xDE_EFTOmega.dat')
omega.shape
# Out:
# (7, 100)

# %%
avec1=np.zeros(100)
for i in range(100):
    avec1[i] = 0.001+i*(1-0.001)/99

# %%
np.max(omega[:,99])
# Out:
# -0.42555045867707098

# %%
for i in range(omega.shape[0]):
    plt.plot(avec1, omega[i,:], color='C0', alpha=0.5)
    
plt.xlim(0,1)
plt.ylim(-.5,.5)
plt.xlabel(r'$a$')
plt.ylabel(r'$\Omega(a)$')
pil.savefig('sampling_xDE_omega_GBD.pdf', bbox_inches='tight')
plt.show()

# %%
cross_corr1 = np.loadtxt('sampler_counts_GBD_plus_xDE_cls_TxW1.dat')
cross_corr2 = np.loadtxt('sampler_counts_GBD_plus_xDE_cls_TxW2.dat')
cross_corr3 = np.loadtxt('sampler_counts_GBD_plus_xDE_cls_TxW3.dat')

# %%
cross_corr1.shape
# Out:
# (8, 799)

# %%
for i in range(cls.shape[0]):   
    plt.semilogx(range(2,cross_corr1.shape[1]+2), cross_corr1[i,:], linewidth=0.5, color='C0', alpha=0.5, zorder=1)
    plt.semilogx(range(2,cross_corr2.shape[1]+2), cross_corr2[i,:], linewidth=0.5, color='C1', alpha=0.5, zorder=2)
    plt.semilogx(range(2,cross_corr3.shape[1]+2), cross_corr3[i,:], linewidth=0.5, color='C2', alpha=0.5, zorder=3)

plt.xlim(2,800)
plt.ylim(-.2,.2)
plt.show()

# %% [markdown]
# ## Pure EFT results

# %%
cls = np.loadtxt('sampler_counts_EFT_poly_xDE_cls_TT.dat')

# %%
cls.shape
# Out:
# (704, 799)

# %%
plt.semilogx(GR_cl[:,0], GR_cl[:,1], label=r'$\Lambda$CDM', linestyle='--', linewidth=1 ,color = 'black', zorder=5)
plt.errorbar(Planck_CMB_TT[:,0], Planck_CMB_TT[:,1], yerr=[Planck_CMB_TT[:,2], Planck_CMB_TT[:,3]], linewidth=0.5, fmt='none', color = 'red', alpha=0.5,zorder=3)
plt.scatter(Planck_CMB_TT[:,0], Planck_CMB_TT[:,1], color='red', alpha=0.5, s=15.0, zorder=4,label='Planck TT')


for i in range(cls.shape[0]-1):   
    #if (abs(omega[i,99]) <0.2):
    #    color = 'C0'
    #    zorder = 1
    #else: 
    #    color = 'C0'
    #    zorder = 1
    
    color = 'C0'
    zorder = 1
    plt.semilogx(range(2,cls.shape[1]+2), cls[i,:], linewidth=0.5, color=color, alpha=0.05, zorder=zorder)

#plt.semilogx(range(2,cls.shape[0]+2), cls, linewidth=0.5, color='C0', alpha=0.2)
plt.xlim(2,2000)
plt.ylim(0,7e3)
plt.legend(loc='upper left')
plt.xlabel(r'$\ell$')
plt.ylabel(r'$\ell (\ell+1) / (2 \pi) \, C_{\ell}^{\rm TT}$')
pil.savefig('sampling_cls_test_EFT.pdf', bbox_inches='tight')
plt.show()

# %%
avec = np.loadtxt('sampler_counts_EFT_poly_xDE_a_sample.dat')

# %%
xDE = np.loadtxt('sampler_counts_EFT_poly_xDE_sampled.dat')

# %%
xDE.shape
# Out:
# (704, 40)

# %%
for i in range(xDE.shape[0]):
    plt.plot(avec, xDE[i,:], color = 'C0', alpha=0.1)
plt.axhline(1.0, color='black', label=r'$\Lambda$CDM', linewidth = 1.0, linestyle='--')
plt.legend(loc='lower right')
plt.xlim(0,1)
plt.ylim(-3,2)
plt.xlabel(r'$a$')
plt.ylabel(r'$X(a)$')
pil.savefig('sampling_xDE_test_EFT.pdf', bbox_inches='tight')
plt.show()

# %%
omega = np.loadtxt('sampler_counts_EFT_poly_xDE_EFTOmega.dat')
omega.shape
# Out:
# (704, 100)

# %%
for i in range(omega.shape[0]):
    color = 'C0'
    zorder = 2
    alpha = 0.05
    #for j in range(omega.shape[1]):
    #    if (abs(omega[i,j]) > 0.2):
    #        color = 'C2'
    #        zorder = 1
    #        alpha=0.1
        
            
        
    plt.plot(avec1, omega[i,:], color=color, alpha=alpha, zorder = zorder)
    
plt.xlim(0,1)
plt.ylim(-.7,.9)
plt.xlabel(r'$a$')
plt.ylabel(r'$\Omega(a)')
pil.savefig('sampling_xDE_omega_EFT.pdf', bbox_inches = 'tight')
plt.show()

# %%
cross_corr1 = np.loadtxt('sampler_counts_EFT_poly_xDE_cls_TxW1.dat')
cross_corr2 = np.loadtxt('sampler_counts_EFT_poly_xDE_cls_TxW2.dat')
cross_corr3 = np.loadtxt('sampler_counts_EFT_poly_xDE_cls_TxW3.dat')

# %%
for i in range(cls.shape[0]):   
    plt.semilogx(range(2,cross_corr1.shape[1]+2), cross_corr1[i,:], linewidth=0.5, color='C0', alpha=0.1, zorder=1)
    plt.semilogx(range(2,cross_corr2.shape[1]+2), cross_corr2[i,:], linewidth=0.5, color='C1', alpha=0.1, zorder=2)
    plt.semilogx(range(2,cross_corr3.shape[1]+2), cross_corr3[i,:], linewidth=0.5, color='C2', alpha=0.1, zorder=3)
plt.ylim(-0.2,0.2)
plt.xlim(2,800)
pil.savefig('sampling_xDE_ISW_pureEFT.pdf', bbox_inches= 'tight')
plt.show()

# %% [markdown]
# # EFTCAMB results
#
# Plotting some results from EFTCAMB.
#
# This part is still work in progress as I need to produce the results for the reconstructed GBD theories for the different reconstructed $X(a)$ (the interpolation of Yuting binning).
#
# We start by importing the libraries for plotting.

# %%
# importing the libraries
import numpy as np
import matplotlib as mpl
import pylab as pil
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib import rc
from math import *

# %%
# seaborn is just a style for plotting
import seaborn as sns
sns.set()
sns.set_context("notebook")

# %% [markdown]
# ## 1.1. Loading Planck Cls data

# %%
Planck_CMB_TT = np.loadtxt('Planck_CMB_TT_spectra.dat')

# %% [markdown]
# ## 1.2. Loading the data
#
# Here we load the results from CAMB.

# %%
# loading the base LCDM (Planck 2015) CMB spectra and matter power spectrum
GR_cl  = np.loadtxt('testGR_scalCls.dat')
GR_pk = np.loadtxt('testGR_matterpower.dat')

# Loading the CMB spectra obtained using an interpolation of the 33 bins.
#GBD1_cl = np.loadtxt('GBD(51)3test2_scalCls.dat')
#GBD2_cl = np.loadtxt('GBD(52)3test2_scalCls.dat')
#GBD3_cl = np.loadtxt('GBD(53)3test2_scalCls.dat')

GBD1_cl = np.loadtxt('GBD_DE21_p2s_scalCls.dat')
GBD2_cl = np.loadtxt('GBD_DE5_std_p2s_trial_scalCls.dat')
GBD3_cl = np.loadtxt('GBD_DE51_p1s_trial_scalCls.dat')



# Loading the CMB spectra obtained from the tanh fitting to DE
#fit1_cl = np.loadtxt('GBD_DE21_coup3_a0p1_dphi0p0_scalCls.dat')
#fit2_cl = np.loadtxt('GBD_DE21_coup3_a0p032_dphi0p0_scalCls.dat')
#fit3_cl = np.loadtxt('GBD_DE21_coup3_a0p01_dphi0p0_scalCls.dat')
#fit4_cl = np.loadtxt('GBD_DE21_coup3_a0p032_dphi2p5_scalCls.dat')
#fit5_cl = np.loadtxt('GBD_DE21_coup3_a0p032_dphi5p0_scalCls.dat')
#fit6_cl = np.loadtxt('GBD_DE21_coup3_a0p032_dphi7p5_scalCls.dat')


# Matter power spectra results from the tanh fitting to DE
#fit1_pk = np.loadtxt('GBD_DE21_coup3_a0p1_dphi0p0_matterpower.dat')
#fit2_pk = np.loadtxt('GBD_DE21_coup3_a0p032_dphi0p0_matterpower.dat')
#fit3_pk = np.loadtxt('GBD_DE21_coup3_a0p01_dphi0p0_matterpower.dat')
#fit4_pk = np.loadtxt('GBD_DE21_coup3_a0p032_dphi2p5_matterpower.dat')
#fit5_pk = np.loadtxt('GBD_DE21_coup3_a0p032_dphi5p0_matterpower.dat')
#fit6_pk = np.loadtxt('GBD_DE21_coup3_a0p032_dphi7p5_matterpower.dat')

# %%
plt.semilogx(GR_cl[:,0], GR_cl[:,1], label=r'$\Lambda$CDM')
plt.semilogx(GBD1_cl[:,0], GBD1_cl[:,1], label='GBD1')
plt.semilogx(GBD2_cl[:,0], GBD2_cl[:,1], label='GBD2')
plt.semilogx(GBD3_cl[:,0], GBD3_cl[:,1], label='GBD3')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## 2. Exploratory Plots
#
# ### 2.1. CMB Temperature Anisotropies power spectrum
#
# In this part we show a few plots.

# %%
# Plotting the LCDM TT spectrum
plt.semilogx(GR_cl[:,0], GR_cl[:,1], linewidth=2, color = 'C0', label = r'$\Lambda$CDM')

# plotting the Planck data
plt.errorbar(Planck_CMB_TT[:,0], Planck_CMB_TT[:,1], yerr=[Planck_CMB_TT[:,2], Planck_CMB_TT[:,3]], fmt='none', color = 'red', alpha=0.35)#, s=1.0)
plt.scatter(Planck_CMB_TT[:,0], Planck_CMB_TT[:,1], color='red', alpha=0.45, s=15.0)


# Plotting the GBD TT spectra (from tanh fitting)
plt.semilogx(fit2_cl[:,0], fit2_cl[:,1], linewidth = 2, color = 'C1', linestyle='--', label = r'$a_{\rm ini} = 0.032$, $\phi_{\rm ini}^{\prime}=0$')
plt.semilogx(fit4_cl[:,0], fit4_cl[:,1], linewidth = 2, color = 'C2', linestyle='--', label = r'$a_{\rm ini} = 0.032$, $\phi_{\rm ini}^{\prime}=-2.5 \times10^{-7}$')
plt.semilogx(fit5_cl[:,0], fit5_cl[:,1], linewidth = 2, color = 'C3', linestyle='--', label = r'$a_{\rm ini} = 0.032$, $\phi_{\rm ini}^{\prime}=-5 \times10^{-7}$')
plt.semilogx(fit6_cl[:,0], fit6_cl[:,1], linewidth = 2, color = 'C4', linestyle='--', label = r'$a_{\rm ini} = 0.032$, $\phi_{\rm ini}^{\prime}=-7.5 \times10^{-7}$')

# labels, legend and limits
plt.xlabel(r'$\ell$')
plt.ylabel(r'$\ell(\ell+1) C_{\ell}^{TT} / 2 \pi $ $[\mu K]^2$')
plt.legend(loc='upper left')
plt.xlim(2,2100)
#plt.figure(figsize=(15,10))
#pil.savefig('GBD_scalCls_1.pdf', bbox_inches='tight')
plt.show()

# %%
# plotting the % difference for the GBD (tanh fit)
plt.semilogx(fit2_cl[:,0], (fit2_cl[:,1]-GR_cl[:,1])/GR_cl[:,1], label = r'$a_{\rm ini} = 0.032$, $\phi_{\rm ini}^{\prime}=0$',                 color='C1', linestyle='--')
plt.semilogx(fit4_cl[:,0], (fit4_cl[:,1]-GR_cl[:,1])/GR_cl[:,1], label = r'$a_{\rm ini} = 0.032$, $\phi_{\rm ini}^{\prime}=-2.5\times10^{-7}$', color='C2', linestyle='--')
plt.semilogx(fit5_cl[:,0], (fit5_cl[:,1]-GR_cl[:,1])/GR_cl[:,1], label = r'$a_{\rm ini} = 0.032$, $\phi_{\rm ini}^{\prime}=-5\times10^{-7}$',   color='C3', linestyle='--')
plt.semilogx(fit6_cl[:,0], (fit6_cl[:,1]-GR_cl[:,1])/GR_cl[:,1], label = r'$a_{\rm ini} = 0.032$, $\phi_{\rm ini}^{\prime}=-7.5\times10^{-7}$', color='C3', linestyle='--')



plt.xlim(2,2300)
plt.ylim(-0.25,0.25)
plt.legend(loc = 'upper left')
plt.ylabel(r'$\Delta C_{\ell} \% $')
plt.xlabel(r'$\ell$')
#pil.savefig('GBD_scalCls_2.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 2.2 Matter Power Spectrum

# %%
plt.loglog(GR_pk[:,0], GR_pk[:,1], label=r'$\Lambda$CDM')
plt.loglog(fit2_pk[:,0], fit2_pk[:,1], label=r'$a_{\rm ini} = 0.032$, $\phi_{\rm ini}^{\prime}=-0$')
plt.loglog(fit4_pk[:,0], fit4_pk[:,1], label=r'$a_{\rm ini} = 0.032$, $\phi_{\rm ini}^{\prime}=-2.5\times10^{-7}$')
plt.loglog(fit5_pk[:,0], fit5_pk[:,1], label=r'$a_{\rm ini} = 0.032$, $\phi_{\rm ini}^{\prime}=-5\times10^{-7}$')
plt.loglog(fit6_pk[:,0], fit6_pk[:,1], label=r'$a_{\rm ini} = 0.032$, $\phi_{\rm ini}^{\prime}=-7.5\times10^{-7}$')

plt.xlim(0.0001,2)
plt.xlabel(r'$k$ $h/$Mpc')
plt.ylabel(r'P(k)')
plt.legend(loc='lower left')
plt.show()

# %%
plt.semilogx(fit2_pk[:,0], (fit2_pk[:,1]-GR_pk[:,1])/GR_pk[:,1], label = r'$a_{\rm ini} = 0.032$, $\phi_{\rm ini}^{\prime}=0$', color = 'C1')
plt.semilogx(fit4_pk[:,0], (fit4_pk[:,1]-GR_pk[:,1])/GR_pk[:,1], label = r'$a_{\rm ini} = 0.032$, $\phi_{\rm ini}^{\prime}=-2.5\times10^{-7}$', color = 'C2')
plt.semilogx(fit5_pk[:,0], (fit5_pk[:,1]-GR_pk[:,1])/GR_pk[:,1], label = r'$a_{\rm ini} = 0.032$, $\phi_{\rm ini}^{\prime}=-5\times10^{-7}$', color = 'C3')
plt.semilogx(fit6_pk[:,0], (fit6_pk[:,1]-GR_pk[:,1])/GR_pk[:,1], label = r'$a_{\rm ini} = 0.032$, $\phi_{\rm ini}^{\prime}=-7.5\times10^{-7}$', color = 'C4')

plt.legend(loc='upper left')
plt.xlabel(r'$k \, \, [h / {\rm Mpc}]$', fontsize=12)
plt.ylabel(r'$\Delta P(k)$', fontsize=12)
plt.xlim(0.0001, 2)
plt.ylim(0,1.45)
plt.show()

# %% [markdown]
# ## CMB and $P_m(k)$ plots for the paper

# %%
# trying to make a nice plot for the paper
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 7))
fig.subplots_adjust(hspace=0.2, wspace = 0.2)
ax1 = axes.flat[0]
ax2 = axes.flat[2]
ax3 = axes.flat[1]
ax4 = axes.flat[3]

ax1=plt.subplot(2,2,1)
ax1.semilogx(GR_cl[:,0], GR_cl[:,1], label=r'$\Lambda$CDM')
ax1.semilogx(fit2_cl[:,0], fit2_cl[:,1], label = r'$a_{\rm ini} = 0.032$, $\phi_{\rm ini}^{\prime}=0$', linestyle='-')
ax1.semilogx(fit4_cl[:,0], fit4_cl[:,1], label = r'$a_{\rm ini} = 0.032$, $\phi_{\rm ini}^{\prime}=-2.5\times10^{-7}$', linestyle='--')
ax1.semilogx(fit5_cl[:,0], fit5_cl[:,1], label = r'$a_{\rm ini} = 0.032$, $\phi_{\rm ini}^{\prime}=-5\times10^{-7}$', linestyle='-.')
ax1.semilogx(fit6_cl[:,0], fit6_cl[:,1], label = r'$a_{\rm ini} = 0.032$, $\phi_{\rm ini}^{\prime}=-7.5\times10^{-7}$', linestyle=':')

#ax1.set_xlabel(r'$\ell$')
ax1.set_ylabel(r'$\ell (\ell +1) C_{\ell}^{\rm TT} / 2 \pi$ $[\mu K^2]$', fontsize=12)
ax1.legend(loc='upper left')
ax1.set_xlim(2,2200)
ax1.set_ylim(0,7000)


ax2=plt.subplot(2,2,3, sharex = ax1)
ax2.semilogx(fit2_cl[:,0], (fit2_cl[:,1]-GR_cl[:,1])/GR_cl[:,1], label = r'$a_{\rm ini} = 0.1$',  linestyle='-', color = 'C1')
ax2.semilogx(fit4_cl[:,0], (fit4_cl[:,1]-GR_cl[:,1])/GR_cl[:,1], label = r'$a_{\rm ini} = 0.032$',linestyle='--', color = 'C2')
ax2.semilogx(fit5_cl[:,0], (fit5_cl[:,1]-GR_cl[:,1])/GR_cl[:,1], label = r'$a_{\rm ini} = 0.01$', linestyle='-.', color = 'C3')
ax2.semilogx(fit6_cl[:,0], (fit6_cl[:,1]-GR_cl[:,1])/GR_cl[:,1], label = r'$a_{\rm ini} = 0.01$', linestyle=':', color = 'C3')
ax2.set_xlabel(r'$\ell$', fontsize=12)
ax2.set_ylabel(r'$\Delta C_{\ell}^{\rm TT} / 2 \pi$ $[\mu K^2]$', fontsize=12)
ax2.set_xlim(2,2200)
ax2.set_ylim(-0.25,0.25)


ax3 = plt.subplot(2,2,2)
ax3.loglog(GR_pk[:,0], GR_pk[:,1], label=r'$\Lambda$CDM')
ax3.loglog(fit2_pk[:,0], fit2_pk[:,1],linestyle='-', label = r'$a_{\rm ini} = 0.1$')
ax3.loglog(fit4_pk[:,0], fit4_pk[:,1],linestyle='--', label = r'$a_{\rm ini} = 0.032$')
ax3.loglog(fit5_pk[:,0], fit5_pk[:,1],linestyle='-.', label = r'$a_{\rm ini} = 0.01$')
ax3.loglog(fit6_pk[:,0], fit6_pk[:,1],linestyle=':', label = r'$a_{\rm ini} = 0.01$')
#ax13.set_xlabel(r'$\ell$')
ax3.set_xticklabels([])
ax3.set_xlim(0.0001, 2)
ax3.set_ylim(1,7e4)
ax3.set_ylabel(r'$P(k)$', fontsize=12)


ax4 = plt.subplot(2,2,4, sharex = ax3)
ax4.semilogx(fit2_pk[:,0], (fit2_pk[:,1]-GR_pk[:,1])/GR_pk[:,1],linestyle='-', label = r'$a_{\rm ini} = 0.01$, $\phi_{\rm ini}^{\prime} / m_0 = 0$', color = 'C1')
ax4.semilogx(fit4_pk[:,0], (fit4_pk[:,1]-GR_pk[:,1])/GR_pk[:,1],linestyle='--', label = r'$a_{\rm ini} = 0.003$, $\phi_{\rm ini}^{\prime} / m_0 = 0$', color = 'C2')
ax4.semilogx(fit5_pk[:,0], (fit5_pk[:,1]-GR_pk[:,1])/GR_pk[:,1],linestyle='-.', label = r'$a_{\rm ini} = 0.01$, $\phi_{\rm ini}^{\prime} / m_0 = -10^{-7}$', color = 'C3')
ax4.semilogx(fit6_pk[:,0], (fit6_pk[:,1]-GR_pk[:,1])/GR_pk[:,1],linestyle=':', label = r'$a_{\rm ini} = 0.01$, $\phi_{\rm ini}^{\prime} / m_0 = -10^{-7}$', color = 'C3')

ax4.set_xlabel(r'$k \, \, [h / {\rm Mpc}]$', fontsize=12)
ax4.set_ylabel(r'$\Delta P(k)$', fontsize=12)
ax4.set_xlim(0.00011, 2)
ax4.set_ylim(0,1)

pil.savefig('X2_results1.pdf',bbox_inches='tight')
plt.show()

# %%
GBD_sol = np.loadtxt('debug_designer_GBD_2_solution.dat')

# %%
plt.semilogx(GBD_sol[:,0], GBD_sol[:,1])
plt.show()

# %%
fit1_pk = np.loadtxt('GBD_DE21_coup3_a0p1_dphi0p0_matterpower.dat')
fit2_pk = np.loadtxt('GBD_DE21_coup3_a0p032_dphi0p0_matterpower.dat')
fit3_pk = np.loadtxt('GBD_DE21_coup3_a0p01_dphi0p0_matterpower.dat')
GR_pk = np.loadtxt('testGR_matterpower.dat')

# %%
GR_pk.shape
# Out:
# (505, 2)

# %%
plt.loglog(GR_pk[:,0], GR_pk[:,1], label=r'$\Lambda$CDM')
plt.loglog(fit1_pk[:,0], fit1_pk[:,1], label='GBD1')
plt.loglog(fit2_pk[:,0], fit2_pk[:,1], label='GBD2')
plt.loglog(fit3_pk[:,0], fit3_pk[:,1], label='GBD3')
plt.xlabel(r'$k$ $h/$Mpc')
plt.ylabel(r'P(k)')
plt.legend(loc='lower left')
plt.show()

# %%
# other plots: loading data
GBD2_1 = np.loadtxt('GBD2_1_scalCls.dat')
GBD2_5 = np.loadtxt('GBD2_5_scalCls.dat')
GBD2_8 = np.loadtxt('GBD2_8_scalCls.dat')
LCDM = np.loadtxt('testGR_scalCls.dat')

# %%
plt.semilogx(LCDM[:,0], LCDM[:,1], label=r'$\Lambda$CDM')
plt.semilogx(GBD2_1[:,0], GBD2_1[:,1], label = r'$a_{\rm ini} = 0.01$, $\phi_{\rm ini}^{\prime} / m_0 = 0$')
plt.semilogx(GBD2_5[:,0], GBD2_5[:,1], label = r'$a_{\rm ini} = 0.003$, $\phi_{\rm ini}^{\prime} / m_0 = 0$')
plt.semilogx(GBD2_8[:,0], GBD2_8[:,1], label = r'$a_{\rm ini} = 0.01$, $\phi_{\rm ini}^{\prime} / m_0 = -10^{-7}$')
plt.xlabel(r'$\ell$')
plt.ylabel(r'$\ell (\ell +1) C_{\ell}^{\rm TT} / 2 \pi$ $[\mu K^2]$')
plt.legend(loc='upper left')
plt.show()

# %%
# Differences 
GBD2_1D = (GBD2_1 - LCDM)/LCDM
GBD2_5D = (GBD2_5 - LCDM)/LCDM
GBD2_8D = (GBD2_8 - LCDM)/LCDM

# %%
plt.semilogx(GBD2_1[:,0], GBD2_1D[:,1], label = r'$a_{\rm ini} = 0.01$, $\phi_{\rm ini}^{\prime} / m_0 = 0$')
plt.semilogx(GBD2_5[:,0], GBD2_5D[:,1], label = r'$a_{\rm ini} = 0.003$, $\phi_{\rm ini}^{\prime} / m_0 = 0$')
plt.semilogx(GBD2_8[:,0], GBD2_8D[:,1], label = r'$a_{\rm ini} = 0.01$, $\phi_{\rm ini}^{\prime} / m_0 = -10^{-7}$')
plt.xlabel(r'$\ell$')
plt.ylabel(r'$\Delta C_{\ell}^{\rm TT} / 2 \pi$ $[\mu K^2]$')
plt.legend(loc='upper right')
plt.show()

# %%
GBD3_1 = np.loadtxt('GBD3_1_scalCls.dat')
#GBD3_2 = np.loadtxt('GBD3_2_scalCls.dat')
GBD3_3 = np.loadtxt('GBD3_3_scalCls.dat')
GBD3_4 = np.loadtxt('GBD3_4_scalCls.dat')
GBD3_1D = (GBD3_1 - LCDM)/LCDM
#GBD3_2D = (GBD3_2 - LCDM)/LCDM
GBD3_3D = (GBD3_3 - LCDM)/LCDM
GBD3_4D = (GBD3_4 - LCDM)/LCDM

# %%
plt.semilogx(LCDM[:,0], LCDM[:,1], label=r'$\Lambda$CDM')
plt.semilogx(GBD3_1[:,0], GBD3_1[:,1], label = r'$a_{\rm ini} = 0.01$, $\phi_{\rm ini}^{\prime} / m_0 = 0$')
#plt.semilogx(GBD3_2[:,0], GBD3_2[:,1], label = r'$a_{\rm ini} = 0.0056$, $\phi_{\rm ini}^{\prime} / m_0 = 0$')
plt.semilogx(GBD3_3[:,0], GBD3_3[:,1], label = r'$a_{\rm ini} = 0.032$, $\phi_{\rm ini}^{\prime} / m_0 = 0$')
plt.semilogx(GBD3_4[:,0], GBD3_4[:,1], label = r'$a_{\rm ini} = 0.032$, $\phi_{\rm ini}^{\prime} / m_0 = -10^{-7}$')
plt.xlabel(r'$\ell$')
plt.ylabel(r'$\ell (\ell +1) C_{\ell}^{\rm TT} / 2 \pi$ $[\mu K^2]$')
plt.legend(loc='upper left')
plt.show()

# %%
plt.semilogx(GBD3_1[:,0], GBD3_1D[:,1], label = r'$a_{\rm ini} = 0.01$, $\phi_{\rm ini}^{\prime} / m_0 = 0$')
#plt.semilogx(GBD3_2[:,0], GBD3_2D[:,1], label = r'$a_{\rm ini} = 0.0056$, $\phi_{\rm ini}^{\prime} / m_0 = 0$')
plt.semilogx(GBD3_3[:,0], GBD3_3D[:,1], label = r'$a_{\rm ini} = 0.032$, $\phi_{\rm ini}^{\prime} / m_0 = 0$')
plt.semilogx(GBD3_4[:,0], GBD3_4D[:,1], label = r'$a_{\rm ini} = 0.032$, $\phi_{\rm ini}^{\prime} / m_0 = -10^{-7}$')
plt.xlabel(r'$\ell$')
plt.ylabel(r'$\Delta C_{\ell}^{\rm TT} / 2 \pi$ $[\mu K^2]$')
plt.legend(loc='upper right')
plt.show()

# %%
# matter power spectrum: loading data
GBD2_1_pk = np.loadtxt('GBD2_1_matterpower.dat')
GBD2_5_pk = np.loadtxt('GBD2_5_matterpower.dat')
GBD2_8_pk = np.loadtxt('GBD2_8_matterpower.dat')
LCDM_pk = np.loadtxt('testGR_matterpower.dat')

# Differences 
GBD2_1D_pk = (GBD2_1_pk - LCDM_pk)/LCDM_pk
GBD2_5D_pk = (GBD2_5_pk - LCDM_pk)/LCDM_pk
GBD2_8D_pk = (GBD2_8_pk - LCDM_pk)/LCDM_pk

# %%
# trying to make a nice plot for the paper


fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 7))
fig.subplots_adjust(hspace=0.2, wspace = 0.2)
ax1 = axes.flat[0]
ax2 = axes.flat[2]
ax3 = axes.flat[1]
ax4 = axes.flat[3]

ax1=plt.subplot(2,2,1)
ax1.semilogx(LCDM[:,0], LCDM[:,1], label=r'$\Lambda$CDM')
ax1.semilogx(GBD2_1[:,0], GBD2_1[:,1], label = r'$a_{\rm ini} = 0.01$, $\phi_{\rm ini}^{\prime} / m_0 = 0$')
ax1.semilogx(GBD2_5[:,0], GBD2_5[:,1], label = r'$a_{\rm ini} = 0.003$, $\phi_{\rm ini}^{\prime} / m_0 = 0$')
ax1.semilogx(GBD2_8[:,0], GBD2_8[:,1], label = r'$a_{\rm ini} = 0.01$, $\phi_{\rm ini}^{\prime} / m_0 = -10^{-7}$')
#ax1.set_xlabel(r'$\ell$')
ax1.set_ylabel(r'$\ell (\ell +1) C_{\ell}^{\rm TT} / 2 \pi$ $[\mu K^2]$', fontsize=12)
ax1.legend(loc='upper left')
ax1.set_xlim(2,2200)
ax1.set_ylim(0,7000)

ax2=plt.subplot(2,2,3, sharex = ax1)


ax2.semilogx(GBD2_1[:,0], GBD2_1D[:,1], label = r'$a_{\rm ini} = 0.01$, $\phi_{\rm ini}^{\prime} / m_0 = 0$', color = 'C1')
ax2.semilogx(GBD2_5[:,0], GBD2_5D[:,1], label = r'$a_{\rm ini} = 0.003$, $\phi_{\rm ini}^{\prime} / m_0 = 0$',color = 'C2')
ax2.semilogx(GBD2_8[:,0], GBD2_8D[:,1], label = r'$a_{\rm ini} = 0.01$, $\phi_{\rm ini}^{\prime} / m_0 = -10^{-7}$',color = 'C3')
ax2.set_xlabel(r'$\ell$', fontsize=12)
ax2.set_ylabel(r'$\Delta C_{\ell}^{\rm TT} / 2 \pi$ $[\mu K^2]$', fontsize=12)
ax2.set_xlim(2,2200)
ax2.set_ylim(-0.5,0.5)

ax3 = plt.subplot(2,2,2)

ax3.loglog(LCDM_pk[:,0], LCDM_pk[:,1], label=r'$\Lambda$CDM')
ax3.loglog(GBD2_1_pk[:,0], GBD2_1_pk[:,1], label = r'$a_{\rm ini} = 0.01$, $\phi_{\rm ini}^{\prime} / m_0 = 0$')
ax3.loglog(GBD2_5_pk[:,0], GBD2_5_pk[:,1], label = r'$a_{\rm ini} = 0.003$, $\phi_{\rm ini}^{\prime} / m_0 = 0$')
ax3.loglog(GBD2_8_pk[:,0], GBD2_8_pk[:,1], label = r'$a_{\rm ini} = 0.01$, $\phi_{\rm ini}^{\prime} / m_0 = -10^{-7}$')
#ax13.set_xlabel(r'$\ell$')
ax3.set_xticklabels([])
ax3.set_xlim(0.0001, 2)
ax3.set_ylim(0.05, 7e4)
ax3.set_ylabel(r'$P(k)$', fontsize=12)


ax4 = plt.subplot(2,2,4, sharex = ax3)
ax4.semilogx(GBD2_1_pk[:,0], GBD2_1D_pk[:,1], label = r'$a_{\rm ini} = 0.01$, $\phi_{\rm ini}^{\prime} / m_0 = 0$', color = 'C1')
ax4.semilogx(GBD2_5_pk[:,0], GBD2_5D_pk[:,1], label = r'$a_{\rm ini} = 0.003$, $\phi_{\rm ini}^{\prime} / m_0 = 0$', color = 'C2')
ax4.semilogx(GBD2_8_pk[:,0], GBD2_8D_pk[:,1], label = r'$a_{\rm ini} = 0.01$, $\phi_{\rm ini}^{\prime} / m_0 = -10^{-7}$', color = 'C3')
ax4.set_xlabel(r'$k \, \, [h / {\rm Mpc}]$', fontsize=12)
ax4.set_ylabel(r'$\Delta P(k)$', fontsize=12)
ax4.set_xlim(0.00011, 2)
ax4.set_ylim(-0.45,1.45)

pil.savefig('X2_results1.pdf',bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-1fa714aec3d9> in <module>()
#      10
#      11 ax1=plt.subplot(2,2,1)
# ---> 12 ax1.semilogx(LCDM[:,0], LCDM[:,1], label=r'$\Lambda$CDM')
#      13 ax1.semilogx(GBD2_1[:,0], GBD2_1[:,1], label = r'$a_{\rm ini} = 0.01$, $\phi_{\rm ini}^{\prime} / m_0 = 0$')
#      14 ax1.semilogx(GBD2_5[:,0], GBD2_5[:,1], label = r'$a_{\rm ini} = 0.003$, $\phi_{\rm ini}^{\prime} / m_0 = 0$')
#
# NameError: name 'LCDM' is not defined

# %%
GBD3_1 = np.loadtxt('GBD3_1_scalCls.dat')
#GBD3_2 = np.loadtxt('GBD3_2_scalCls.dat')
GBD3_3 = np.loadtxt('GBD3_3_scalCls.dat')
GBD3_4 = np.loadtxt('GBD3_4_scalCls.dat')
GBD3_1D = (GBD3_1 - LCDM)/LCDM
#GBD3_2D = (GBD3_4 - LCDM)/LCDM
GBD3_3D = (GBD3_3 - LCDM)/LCDM
GBD3_4D = (GBD3_4 - LCDM)/LCDM

# matter power spectrum: loading data
GBD3_1_pk = np.loadtxt('GBD3_1_matterpower.dat')
#GBD3_2_pk = np.loadtxt('GBD3_2_matterpower.dat')
GBD3_3_pk = np.loadtxt('GBD3_3_matterpower.dat')
GBD3_4_pk = np.loadtxt('GBD3_4_matterpower.dat')
#LCDM_pk = np.loadtxt('testGR_matterpower.dat')

# Differences 
GBD3_1D_pk = (GBD3_1_pk - LCDM_pk)/LCDM_pk
#GBD3_2D_pk = (GBD3_2_pk - LCDM_pk)/LCDM_pk
GBD3_3D_pk = (GBD3_3_pk - LCDM_pk)/LCDM_pk
GBD3_4D_pk = (GBD3_4_pk - LCDM_pk)/LCDM_pk
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-38-d8d6208ecd72> in <module>()
# ----> 1 GBD3_1 = np.loadtxt('GBD3_1_scalCls.dat')
#       2 #GBD3_2 = np.loadtxt('GBD3_2_scalCls.dat')
#       3 GBD3_3 = np.loadtxt('GBD3_3_scalCls.dat')
#       4 GBD3_4 = np.loadtxt('GBD3_4_scalCls.dat')
#       5 GBD3_1D = (GBD3_1 - LCDM)/LCDM
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     896                 fh = iter(open(fname, 'U'))
#     897             else:
# --> 898                 fh = iter(open(fname))
#     899         else:
#     900             fh = iter(fname)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'GBD3_1_scalCls.dat'

# %%
# trying to make a nice plot for the paper


fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 7))
fig.subplots_adjust(hspace=0.2, wspace = 0.2)
ax1 = axes.flat[0]
ax2 = axes.flat[2]
ax3 = axes.flat[1]
ax4 = axes.flat[3]

ax1=plt.subplot(2,2,1)
ax1.semilogx(GR_cl[:,0], GR_cl[:,1], label=r'$\Lambda$CDM')
ax1.semilogx(fit1_cl[:,0], fit1_cl[:,1], label = r'$a_{\rm ini} = 0.1$', linestyle='--')
ax1.semilogx(fit2_cl[:,0], fit2_cl[:,1], label = r'$a_{\rm ini} = 0.032$', linestyle='--')
ax1.semilogx(fit3_cl[:,0], fit3_cl[:,1], label = r'$a_{\rm ini} = 0.01$', linestyle='--')
#ax1.set_xlabel(r'$\ell$')
ax1.set_ylabel(r'$\ell (\ell +1) C_{\ell}^{\rm TT} / 2 \pi$ $[\mu K^2]$', fontsize=12)
ax1.legend(loc='upper left')
ax1.set_xlim(2,2200)
ax1.set_ylim(0,7000)




ax2=plt.subplot(2,2,3, sharex = ax1)
ax2.semilogx(fit1_cl[:,0], (fit1_cl[:,1]-GR_cl[:,1])/GR_cl[:,1], label = r'$a_{\rm ini} = 0.1$',  linestyle='--', color = 'C1')
ax2.semilogx(fit2_cl[:,0], (fit2_cl[:,1]-GR_cl[:,1])/GR_cl[:,1], label = r'$a_{\rm ini} = 0.032$',linestyle='--', color = 'C2')
ax2.semilogx(fit3_cl[:,0], (fit3_cl[:,1]-GR_cl[:,1])/GR_cl[:,1], label = r'$a_{\rm ini} = 0.01$', linestyle='--', color = 'C3')
ax2.set_xlabel(r'$\ell$', fontsize=12)
ax2.set_ylabel(r'$\Delta C_{\ell}^{\rm TT} / 2 \pi$ $[\mu K^2]$', fontsize=12)
ax2.set_xlim(2,2200)
ax2.set_ylim(-0.5,1)


ax3 = plt.subplot(2,2,2)
ax3.loglog(GR_pk[:,0], GR_pk[:,1], label=r'$\Lambda$CDM')
ax3.loglog(fit1_pk[:,0], fit1_pk[:,1], label = r'$a_{\rm ini} = 0.1$')
ax3.loglog(fit2_pk[:,0], fit2_pk[:,1], label = r'$a_{\rm ini} = 0.032$')
ax3.loglog(fit3_pk[:,0], fit3_pk[:,1], label = r'$a_{\rm ini} = 0.01$')
#ax13.set_xlabel(r'$\ell$')
ax3.set_xticklabels([])
ax3.set_xlim(0.0001, 2)
ax3.set_ylim(0.05,7e4)
ax3.set_ylabel(r'$P(k)$', fontsize=12)


ax4 = plt.subplot(2,2,4, sharex = ax3)
ax4.semilogx(fit1_pk[:,0], (fit1_pk[:,1]-GR_pk[:,1])/GR_pk[:,1], label = r'$a_{\rm ini} = 0.01$, $\phi_{\rm ini}^{\prime} / m_0 = 0$', color = 'C1')
ax4.semilogx(fit2_pk[:,0], (fit2_pk[:,1]-GR_pk[:,1])/GR_pk[:,1], label = r'$a_{\rm ini} = 0.003$, $\phi_{\rm ini}^{\prime} / m_0 = 0$', color = 'C2')
ax4.semilogx(fit3_pk[:,0], (fit3_pk[:,1]-GR_pk[:,1])/GR_pk[:,1], label = r'$a_{\rm ini} = 0.01$, $\phi_{\rm ini}^{\prime} / m_0 = -10^{-7}$', color = 'C3')
ax4.set_xlabel(r'$k \, \, [h / {\rm Mpc}]$', fontsize=12)
ax4.set_ylabel(r'$\Delta P(k)$', fontsize=12)
ax4.set_xlim(0.00011, 2)
ax4.set_ylim(-0.5,1.45)

pil.savefig('X2_results1.pdf',bbox_inches='tight')
plt.show()

# %%
# other plots: function X3.
#laod the data
GBD4_1 = np.loadtxt('GBD4_1_scalCls.dat')
GBD4_2 = np.loadtxt('GBD4_2_scalCls.dat')
GBD4_3 = np.loadtxt('GBD4_3_scalCls.dat')
GBD4_4 = np.loadtxt('GBD4_4_scalCls.dat')

# matter power spectrum data
GBD4_1_pk = np.loadtxt('GBD4_1_matterpower.dat')
GBD4_2_pk = np.loadtxt('GBD4_2_matterpower.dat')
GBD4_3_pk = np.loadtxt('GBD4_3_matterpower.dat')
GBD4_4_pk = np.loadtxt('GBD4_4_matterpower.dat')

# CMB cls differences
GBD4_1D = (GBD4_1 - LCDM)/LCDM
GBD4_2D = (GBD4_2 - LCDM)/LCDM
GBD4_3D = (GBD4_3 - LCDM)/LCDM
GBD4_4D = (GBD4_4 - LCDM)/LCDM

# matter power spectrum differences
GBD4_1D_pk = (GBD4_1_pk - LCDM_pk)/LCDM_pk
GBD4_2D_pk = (GBD4_2_pk - LCDM_pk)/LCDM_pk
GBD4_3D_pk = (GBD4_3_pk - LCDM_pk)/LCDM_pk
GBD4_4D_pk = (GBD4_4_pk - LCDM_pk)/LCDM_pk

# %%
# trying to make a nice plot for the paper


fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 7))
fig.subplots_adjust(hspace=0, wspace = 0.2)
ax1 = axes.flat[0]
ax2 = axes.flat[2]
ax3 = axes.flat[1]
ax4 = axes.flat[3]

ax1=plt.subplot(2,2,1)
ax1.semilogx(LCDM[:,0], LCDM[:,1], label=r'$\Lambda$CDM')
ax1.semilogx(GBD4_1[:,0], GBD4_1[:,1], label = r'$a_{\rm ini} = 0.01$, $\phi_{\rm ini}^{\prime} / m_0 = 0$')
ax1.semilogx(GBD4_2[:,0], GBD4_2[:,1], label = r'$a_{\rm ini} = 0.031$, $\phi_{\rm ini}^{\prime} / m_0 = 0$')
ax1.semilogx(GBD4_3[:,0], GBD4_3[:,1], label = r'$a_{\rm ini} = 0.063$, $\phi_{\rm ini}^{\prime} / m_0 = 0$')
ax1.semilogx(GBD4_4[:,0], GBD4_4[:,1], label = r'$a_{\rm ini} = 0.1$, $\phi_{\rm ini}^{\prime} / m_0 = 0$')
#ax1.set_xlabel(r'$\ell$')
ax1.set_ylabel(r'$\ell (\ell +1) C_{\ell}^{\rm TT} / 2 \pi$ $[\mu K^2]$', fontsize=12)
ax1.legend(loc='upper left')
ax1.set_xlim(2,2300)



ax2=plt.subplot(2,2,3, sharex = ax1)
ax2.semilogx(GBD4_1[:,0], GBD4_1D[:,1], label = r'$a_{\rm ini} = 0.01$, $\phi_{\rm ini}^{\prime} / m_0 = 0$', color = 'C1')
ax2.semilogx(GBD4_2[:,0], GBD4_2D[:,1], label = r'$a_{\rm ini} = 0.003$, $\phi_{\rm ini}^{\prime} / m_0 = 0$',color = 'C2')
ax2.semilogx(GBD4_3[:,0], GBD4_3D[:,1], label = r'$a_{\rm ini} = 0.003$, $\phi_{\rm ini}^{\prime} / m_0 = 0$',color = 'C3')
ax2.semilogx(GBD4_4[:,0], GBD4_4D[:,1], label = r'$a_{\rm ini} = 0.003$, $\phi_{\rm ini}^{\prime} / m_0 = 0$',color = 'C4')
ax2.set_ylabel(r'$\Delta C_{\ell}^{\rm TT} / 2 \pi$ $[\mu K^2]$', fontsize=12)
ax2.set_xlim(2,2300)



ax3 = plt.subplot(2,2,2)
ax3.loglog(LCDM_pk[:,0], LCDM_pk[:,1], label=r'$\Lambda$CDM')
ax3.loglog(GBD4_1_pk[:,0], GBD4_1_pk[:,1], label = r'$a_{\rm ini} = 0.01$, $\phi_{\rm ini}^{\prime} / m_0 = 0$')
ax3.loglog(GBD4_2_pk[:,0], GBD4_2_pk[:,1], label = r'$a_{\rm ini} = 0.003$, $\phi_{\rm ini}^{\prime} / m_0 = 0$')
ax3.loglog(GBD4_3_pk[:,0], GBD4_3_pk[:,1], label = r'$a_{\rm ini} = 0.003$, $\phi_{\rm ini}^{\prime} / m_0 = 0$')
ax3.loglog(GBD4_4_pk[:,0], GBD4_4_pk[:,1], label = r'$a_{\rm ini} = 0.003$, $\phi_{\rm ini}^{\prime} / m_0 = 0$')
#ax13.set_xlabel(r'$\ell$')
ax3.set_xticklabels([])
ax3.set_xlim(0.0001, 2)
ax3.set_ylabel(r'$P(k)$', fontsize=12)


ax4 = plt.subplot(2,2,4, sharex = ax3)
ax4.semilogx(GBD4_1_pk[:,0], GBD4_1D_pk[:,1], label = r'$a_{\rm ini} = 0.01$, $\phi_{\rm ini}^{\prime} / m_0 = 0$', color = 'C1')
ax4.semilogx(GBD4_2_pk[:,0], GBD4_2D_pk[:,1], label = r'$a_{\rm ini} = 0.003$, $\phi_{\rm ini}^{\prime} / m_0 = 0$', color = 'C2')
ax4.semilogx(GBD4_3_pk[:,0], GBD4_3D_pk[:,1], label = r'$a_{\rm ini} = 0.003$, $\phi_{\rm ini}^{\prime} / m_0 = 0$', color = 'C3')
ax4.semilogx(GBD4_4_pk[:,0], GBD4_4D_pk[:,1], label = r'$a_{\rm ini} = 0.003$, $\phi_{\rm ini}^{\prime} / m_0 = 0$', color = 'C4')
ax4.set_xlabel(r'$k \, \, [h / {\rm Mpc}]$', fontsize=12)
ax4.set_ylabel(r'$\Delta P(k)$', fontsize=12)
ax4.set_xlim(0.00011, 2)
ax4.set_ylim(0,1.45)

pil.savefig('X4_results1.pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# ## ISW effect analysis
#
# In this part we investigate the ISW effect of the reconstructed GBD theories.

# %%
import pandas as pd

# %%
data1 = np.loadtxt('GBD_DE21_coup3_a0p032_dphi0p0_cache_MetricMG.dat')
data2 = np.loadtxt('GBD_DE21_coup3_a0p01_dphi0p0_cache_MetricMG.dat')
data3 = np.loadtxt('GBD_DE21_coup3_a0p1_dphi0p0_cache_MetricMG.dat')
#data4 = np.loadtxt('EFTpow51test1_cache_MetricMG.dat')

# %%
data1.shape
# Out:
# (84444, 7)

# %%
df = pd.DataFrame(data1)
columns = ['a','tau','k','Psi','Phi','mu', 'gamma']
df.columns=columns
df.head()
# Out:
#           a          tau         k       Psi       Phi        mu  gamma
# 0  0.010190  1353.472707  0.000007 -0.388008 -0.611992  0.657519    0.0
# 1  0.010555  1381.517948  0.000007 -0.388338 -0.611662  0.657743    0.0
# 2  0.010926  1409.563189  0.000007 -0.388655 -0.611345  0.657960    0.0
# 3  0.011303  1437.608430  0.000007 -0.388960 -0.611040  0.658170    0.0
# 4  0.011687  1465.653670  0.000007 -0.389253 -0.610746  0.658374    0.0

# %%
df2 = pd.DataFrame(data2)
columns = ['a','tau','k','Psi','Phi','mu', 'gamma']
df2.columns=columns
df2.head()
# Out:
#           a          tau         k       Psi       Phi        mu  gamma
# 0  0.010190  1353.472707  0.000007 -0.388008 -0.611992  0.657519    0.0
# 1  0.010555  1381.517948  0.000007 -0.388338 -0.611662  0.657743    0.0
# 2  0.010926  1409.563189  0.000007 -0.388655 -0.611345  0.657960    0.0
# 3  0.011303  1437.608430  0.000007 -0.388960 -0.611040  0.658170    0.0
# 4  0.011687  1465.653670  0.000007 -0.389253 -0.610746  0.658374    0.0

# %%
df3 = pd.DataFrame(data3)
columns = ['a','tau','k','Psi','Phi','mu', 'gamma']
df3.columns=columns
df3.head()
# Out:
#           a          tau         k       Psi       Phi        mu  gamma
# 0  0.010190  1353.472707  0.000007 -0.388008 -0.611992  0.657519    0.0
# 1  0.010555  1381.517948  0.000007 -0.388338 -0.611662  0.657743    0.0
# 2  0.010926  1409.563189  0.000007 -0.388655 -0.611345  0.657960    0.0
# 3  0.011303  1437.608430  0.000007 -0.388960 -0.611040  0.658170    0.0
# 4  0.011687  1465.653670  0.000007 -0.389253 -0.610746  0.658374    0.0

# %%
#df4 = pd.DataFrame(data4)
#columns = ['a','tau','k','Psi','Phi','mu', 'gamma']
#df4.columns=columns
#df4.head()

# %%
# which kvalues do we have?
ks1 = list(np.unique(df["k"]))
ks2 = list(np.unique(df2["k"]))
ks3 = list(np.unique(df3["k"]))
#ks4 = list(np.unique(df4["k"]))
print(ks1)
# Out:
# [7.0897496819999997e-06, 7.828187316e-06, 8.6435374179999995e-06, 9.5438108569999999e-06, 1.053785288e-05, 1.163543002e-05, 1.284732603e-05, 1.4185447899999999e-05, 1.5662942740000001e-05, 1.7294327050000001e-05, 1.9095629279999998e-05, 2.108454736e-05, 2.328062254e-05, 2.5705431400000001e-05, 2.8382797849999999e-05, 3.1339027200000003e-05, 3.4603164599999999e-05, 3.8207280429999997e-05, 4.2186785349999997e-05, 4.6580778280000001e-05, 5.1432430490000003e-05, 5.6789409790000003e-05, 6.2704348870000002e-05, 6.9235362390000004e-05, 7.6446618010000007e-05, 8.4408966799999998e-05, 9.3200639360000004e-05, 0.00010290801449999999, 0.0001136264678, 0.00012546130869999999, 0.00013852881550000001, 0.0001529573772, 0.0001688887555, 0.0001864794771, 0.00020590237220000001, 0.00022734827190000001, 0.00025102788359999999, 0.00027717386129999999, 0.00030604309070000001, 0.00033791921420000002, 0.00037311541659999998, 0.00041197750320000001, 0.00045488729639999999, 0.00050226638790000001, 0.000554580
# ...

# %%
print(ks2)
# Out:
# [7.0897496819999997e-06, 7.828187316e-06, 8.6435374179999995e-06, 9.5438108569999999e-06, 1.053785288e-05, 1.163543002e-05, 1.284732603e-05, 1.4185447899999999e-05, 1.5662942740000001e-05, 1.7294327050000001e-05, 1.9095629279999998e-05, 2.108454736e-05, 2.328062254e-05, 2.5705431400000001e-05, 2.8382797849999999e-05, 3.1339027200000003e-05, 3.4603164599999999e-05, 3.8207280429999997e-05, 4.2186785349999997e-05, 4.6580778280000001e-05, 5.1432430490000003e-05, 5.6789409790000003e-05, 6.2704348870000002e-05, 6.9235362390000004e-05, 7.6446618010000007e-05, 8.4408966799999998e-05, 9.3200639360000004e-05, 0.00010290801449999999, 0.0001136264678, 0.00012546130869999999, 0.00013852881550000001, 0.0001529573772, 0.0001688887555, 0.0001864794771, 0.00020590237220000001, 0.00022734827190000001, 0.00025102788359999999, 0.00027717386129999999, 0.00030604309070000001, 0.00033791921420000002, 0.00037311541659999998, 0.00041197750320000001, 0.00045488729639999999, 0.00050226638790000001, 0.000554580
# ...

# %%
print(ks3)
# Out:
# [7.0897496819999997e-06, 7.828187316e-06, 8.6435374179999995e-06, 9.5438108569999999e-06, 1.053785288e-05, 1.163543002e-05, 1.284732603e-05, 1.4185447899999999e-05, 1.5662942740000001e-05, 1.7294327050000001e-05, 1.9095629279999998e-05, 2.108454736e-05, 2.328062254e-05, 2.5705431400000001e-05, 2.8382797849999999e-05, 3.1339027200000003e-05, 3.4603164599999999e-05, 3.8207280429999997e-05, 4.2186785349999997e-05, 4.6580778280000001e-05, 5.1432430490000003e-05, 5.6789409790000003e-05, 6.2704348870000002e-05, 6.9235362390000004e-05, 7.6446618010000007e-05, 8.4408966799999998e-05, 9.3200639360000004e-05, 0.00010290801449999999, 0.0001136264678, 0.00012546130869999999, 0.00013852881550000001, 0.0001529573772, 0.0001688887555, 0.0001864794771, 0.00020590237220000001, 0.00022734827190000001, 0.00025102788359999999, 0.00027717386129999999, 0.00030604309070000001, 0.00033791921420000002, 0.00037311541659999998, 0.00041197750320000001, 0.00045488729639999999, 0.00050226638790000001, 0.000554580
# ...

# %%
#print(ks4)

# %%
# choose one k only now:
k=  0.01083611592

# %%
dfk = df.loc[(df["k"]==k)]

# %%
dfk2 = df2.loc[(df2["k"]==k)]

# %%
dfk3 = df3.loc[(df3["k"]==k)]

# %%
#dfk4 = df4.loc[(df4["k"]==0.010830725120000001)]

# %%
#dfk4.head()

# %%
avec1 = dfk['a'].values
avec2 = dfk2['a'].values
avec3 = dfk3['a'].values
#avec4 = dfk4['a'].values

# %%
psivec1 = dfk['Psi'].values
phivec1 = dfk['Phi'].values
psivec2 = dfk2['Psi'].values
phivec2 = dfk2['Phi'].values
psivec3 = dfk3['Psi'].values
phivec3 = dfk3['Phi'].values
#psivec4 = dfk4['Psi'].values
#phivec4 = dfk4['Phi'].values

# %%
# the LCDM model now
dataLCDM = np.loadtxt('fort.1')

# %%
import seaborn as sns
sns.set()

# %%
# A simple window function
z = np.linspace(0,2,300)
A = 1
zc1 = 0.2
sz1 = 0.05
zc2 = 0.5
sz2 = 0.06
zc3 = 1.0
sz3 = 0.1
win1 = A*np.exp(-(z-zc1)**2/(2*sz1**2))
win2 = A*np.exp(-(z-zc2)**2/(2*sz2**2))
win3 = A*np.exp(-(z-zc3)**2/(2*sz3**2))

# plotting the stuff
# Lensing potential of LCDM
plt.plot(1/dataLCDM[:,0]-1, -dataLCDM[:,3], label = r'$\Lambda$CDM')

# Window function (if needed)
#plt.plot(z,win1, color='black')
plt.fill_between(z,0,win1, color='gray', alpha=.5)
#plt.plot(z,win2, color='black')
plt.fill_between(z,0,win2, color='gray', alpha=.5)
#plt.plot(z,win3, color='black')
plt.fill_between(z,0,win3, color='gray', alpha=.5)

# Lensing potential of modified gravity
plt.plot(1/avec1-1, -psivec1-phivec1, linestyle=':', label=r'$a_{\rm ini} = 0.032$')
plt.plot(1/avec2-1, -psivec2-phivec2, linestyle=':', label=r'$a_{\rm ini} = 0.01$')
plt.plot(1/avec3-1, -psivec3-phivec3, linestyle=':', label=r'$a_{\rm ini} = 0.1$')
#plt.plot(1/avec4-1, -psivec4-phivec4, linestyle=':', label=r'EFTpow1')
plt.xlabel(r'$z$', fontsize=12)
plt.ylabel(r'$\Psi+\Phi$', fontsize = 12)
plt.legend(loc='lower right')
plt.xlim(0,2)
plt.ylim(0,1.05)
pil.savefig('PsiPhiISW.pdf', bbox_inches='tight')
plt.show()
